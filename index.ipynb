# %% [markdown]
# ## Numerische Strömungssimulation 1
#
# [Prof. Dr.-Ing. Matthias Stripf](mailto:matthias.stripf@hs-karlsruhe.de), [Florian Theobald](mailto:florian.theobald@hs-karlsruhe.de)
#
#
# ### Molekulardynamik
# - [Einführung in Python](1_1-Einfuehrung_in_Python.ipynb)
# - [Molekulardynamik Einführung](1_2-Molekulardynamik_Einfuehrung.ipynb)
# - [Molekulardynamik Simulation](1_3-Molekulardynamik_Simulation.ipynb)<br><br>
#
# ### Kontinuumsströmungen
# - [Einführung](2_1-Kontinuumsstroemungen_Einfuehrung.ipynb)
# - [Die Navier-Stokes-Gleichungen](2_2-Kontinuumsstroemungen_Navier-Stokes-Gleichungen.ipynb)
# - [Die Navier-Stokes-Gleichungen 2D](2_3-Kontinuumsstroemungen_Navier-Stokes-Gleichungen-2D.ipynb)<br><br>
#
# ### Numerische Lösungsverfahren
# - [Iterative Verfahren](3_1-Numerik_Iterative_Verfahren.ipynb)
# - [Anfangswertaufgaben](3_2-Numerik_Anfangswertaufgaben.ipynb)
# - [Randwertaufgaben](3_3-Numerik_Randwertaufgaben.ipynb)
# - [Anfangs-Randwertaufgaben](3_4-Numerik_AnfangsRandwertaufgaben.ipynb)<br><br>
#
# ### Potentialtheorie
# - [Einführung in die Potentialtheorie](4_1-Potentialtheorie_Einfuehrung.ipynb)
# - [Elementare Potentialströmungen 1](4_2-Potentialtheorie_Elementarstroemungen.ipynb)
# - [Elementare Potentialströmungen 2](4_3-Potentialtheorie_Elementarstroemungen2.ipynb)
# - [Auftrieb umströmter Körper](4_4-Potentialtheorie_Auftrieb.ipynb)
# - [Das Quell-Panel Verfahren](4_5-Potentialtheorie_Quell-Panel-Verfahren.ipynb)
# - [Das Wirbel-Panel Verfahren](4_6-Potentialtheorie_Wirbel-Panel-Verfahren.ipynb)<br><br>
#
# ### Grenzschichtströmungen
# - in Arbeit ...<br><br>
#
# ### Gasdynamik
# - in Arbeit ...<br><br>

# %% [markdown]
# ---
# ###### Copyright (c) 2019, Florian Theobald und Matthias Stripf
#
# Der folgende Python-Code darf ignoriert werden. Er dient nur dazu, die richtige Formatvorlage für die Jupyter-Notebooks zu laden.

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open('TFDStyle.css', 'r').read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# ...
